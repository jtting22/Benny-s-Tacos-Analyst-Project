# %%
#import package to make HTTP requests (similar to a browser request)
import requests
import json
import pandas as pd

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/David/opt/anaconda3/lib/python3.8/site-packages (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/David/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/David/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/David/opt/anaconda3/lib/python3.8/site-packages (from pandas) (1.20.1)
# Requirement already satisfied: six>=1.5 in /Users/David/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
yelp_rest = pd.DataFrame(None)

for offset_num in range(0, 1000, 50):
    
    
    
    #set params
    
    api_url = 'https://api.yelp.com/v3/businesses/search'
    params = {'term' : 'mexican', 'location' : 'Los Angeles', 'sort_by' : 'distance', 
             'offset': offset_num, 'limit': 50}

    #set key/headers
    
    api_key = 'lHNoGitPyFt2COwE_nMbGDQZM6pmgd0scwqiEDSiV22PKvVjt_eDZxHLJNN5rv1gmMFvlzN05dx0hxuXr47GM1iAB_gbsD4RlpBsvPC7myo4RfzSTwAiHDZYU-3mYXYx'
    headers = {'Authorization' : 'Bearer %s' % api_key}
    
    #make an API request
    
    api_request = requests.get(api_url, params = params, headers=headers) 
    
    #get response for a single page of 50
    
    json.loads(api_request.text)
    api_response = json.loads(api_request.text)
    businesses = api_response['businesses']

    
    business_data = {
    'name' : [],
    'review_count' : [],
    'rating':[],
    'address1':[],
    'address2':[],
    'city':[],
    'city':[],
    'state':[],
    'zip_code':[],
    'url':[],
    'id':[], 
    'latitude':[], 'longitude':[], 'alias':[], 'title':[], 'price':[]
    }



    for business in businesses:
        name = business['name']
        business_data['name'].append(name)
        #print(name)

        review_count = business['review_count']
        business_data['review_count'].append(review_count)
        #print(review_count)

        rating = business['rating']
        business_data['rating'].append(rating)
        #print(rating)

        address1 = business['location']['address1']
        business_data['address1'].append(address1)
        #print(address1)

        address2 = business['location']['address2']
        business_data['address2'].append(address2)
        #print(address2)

        city = business['location']['city']
        business_data['city'].append(city)
        #print(city)

        state = business['location']['state']
        business_data['state'].append(state)
        #print(state)

        zip_code = business['location']['zip_code']
        business_data['zip_code'].append(zip_code)
        #print(zip_code)

        url = business['url']
        business_data['url'].append(url)
        #print(url)

        id = business['id']
        business_data['id'].append(id)
        #print(id)
        
        latitude = business['coordinates']['latitude']
        business_data['latitude'].append(latitude)
        
        long = business['coordinates']['longitude']
        business_data['longitude'].append(long)
                                          
        alias = business['categories'][0]['alias']
        business_data['alias'].append(alias)
        
        title = business['categories'][0]['title']
        business_data['title'].append(title)
        
        
        def hello(num):
            return businesses[num]['price']
        
        for i in range (0,50,1):  
            try:
                hello(i)
            except Exception:
                price = 'NA'
            else:
                price = (businesses[i]['price'])
                
        business_data['price'].append(price)

        #print('-'*75)
        
        # convert Python dict to a pandas dataframe
        
        df = pd.DataFrame(business_data)
        
    yelp_rest = yelp_rest.append(df)
        
    print(offset_num)
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950

# %%
api_response
# Out:
# {'businesses': [{'id': '8PM9bOr2I1i0uT4qEDwRQA',
#    'alias': 'el-ranchito-taco-truck-los-angeles',
#    'name': 'El Ranchito Taco Truck',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-ranchito-taco-truck-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 4,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 34.0475377, 'longitude': -118.227497},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1202 E 1st St',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90033',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1202 E 1st St', 'Los Angeles, CA 90033']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 8782.156191631631},
#   {'id': 'CyJTSB0KyD_0Rm7rAMxjow',
#    'alias': 'fuente-restaurant-los-angeles',
#    'name': 'Fuente Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9vMBzX5owa--Di2AbVKeMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fuente-restaurant-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 43,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'salvadoran', 'title': 'Salvadoran'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 33.9866103629108,
#     'longitude': -118.291323568684},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '5916 S Vermont Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90044',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5916 S Vermont Ave', 'Los Angeles, CA 90044']},
#    'phone': '+13239711854',
#    'display_phone': '(323) 971-1854',
#    'distance': 8785.411768801065},
#   {'id': 'M85k4ql2ytbKjVr_Cz3rSg',
#    'alias': 'el-rinconcito-de-mago-los-angeles',
#    'name': 'El Rinconcito de Mago',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lo-NxxGUUQQEgkMWg4SVqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-rinconcito-de-mago-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 11,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 34.019674482423,
#     'longitude': -118.240189813077},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1901 S Alameda St',
#     'address2': 'Ste 115',
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90058',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1901 S Alameda St',
#      'Ste 115',
#      'Los Angeles, CA 90058']},
#    'phone': '+12137457894',
#    'display_phone': '(213) 745-7894',
#    'distance': 8814.040074272089},
#   {'id': '_tDl_7eBJeixtv7pwZdnfQ',
#    'alias': 'pepes-tacos-los-angeles-3',
#    'name': "Pepe's Tacos",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xOKSY3vmC9WQAAMMDyvbUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pepes-tacos-los-angeles-3?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 7,
#    'categories': [{'alias': 'streetvendors', 'title': 'Street Vendors'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 33.9944345151047,
#     'longitude': -118.270181268454},
#    'transactions': [],
#    'location': {'address1': '53RD St And San Pedro',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90011',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['53RD St And San Pedro', 'Los Angeles, CA 90011']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 8833.016796099804},
#   {'id': 'ppS_MhoSK4KckpUDscssSg',
#    'alias': 'tacos-el-hermano-los-angeles-2',
#    'name': 'Tacos el Hermano',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JP6xSP7twPQ5RVojtPu_AA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-el-hermano-los-angeles-2?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 42,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 34.0473899841309,
#     'longitude': -118.226928710938},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1220 E 1st St',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90033',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1220 E 1st St', 'Los Angeles, CA 90033']},
#    'phone': '+13236040255',
#    'display_phone': '(323) 604-0255',
#    'distance': 8840.177653181016},
#   {'id': 'wvjfymfnwnP1VFs_lL5JBQ',
#    'alias': 'el-taco-grande-los-angeles',
#    'name': 'El Taco Grande',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QY87OkPd_o7sp-UOUOaIMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-taco-grande-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 27,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.992294, 'longitude': -118.273598},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '5500 S Main St',
#     'address2': None,
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90011',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5500 S Main St', 'Los Angeles, CA 90011']},
#    'phone': '+13232728235',
#    'display_phone': '(323) 272-8235',
#    'distance': 8847.361534196183},
#   {'id': 'L_FSoOxx8NWpemPFXgGzNA',
#    'alias': 'manuels-breakfast-and-lunch-los-angeles',
#    'name': "Manuel's Breakfast & Lunch",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FcGRT8hu2Q1P038iZXTFFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/manuels-breakfast-and-lunch-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 3,
#    'categories': [{'alias': 'streetvendors', 'title': 'Street Vendors'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'importedfood', 'title': 'Imported Food'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 34.0709261854572,
#     'longitude': -118.225873609262},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1745 N Spring St',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90012',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1745 N Spring St', 'Los Angeles, CA 90012']},
#    'phone': '+13237210740',
#    'display_phone': '(323) 721-0740',
#    'distance': 8858.45470949753},
#   {'id': 'Ex4t7M8D-bSvkdYmFzcRmA',
#    'alias': 'cocoy-s-mexican-and-american-food-los-angeles-2',
#    'name': 'Cocoy’s Mexican & American Food',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CPjvWdRyxOTL-XZIqV1qrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cocoy-s-mexican-and-american-food-los-angeles-2?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 1,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 33.98557545881369,
#     'longitude': -118.29195472568685},
#    'transactions': [],
#    'location': {'address1': '6001 S Vermont',
#     'address2': 'Ste 4B',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90044',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6001 S Vermont', 'Ste 4B', 'Los Angeles, CA 90044']},
#    'phone': '+13234550149',
#    'display_phone': '(323) 455-0149',
#    'distance': 8876.754821790453},
#   {'id': 'tcDPEM7vd_SuowRWY9pJMw',
#    'alias': 'fuego-grill-los-angeles-2',
#    'name': 'Fuego Grill',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pyjaB-KukfuzYmWFpK8jRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fuego-grill-los-angeles-2?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 1,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.985528, 'longitude': -118.291887},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '6001 S Vermont Ave',
#     'address2': 'Ste 4',
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90044',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6001 S Vermont Ave',
#      'Ste 4',
#      'Los Angeles, CA 90044']},
#    'phone': '+13235312314',
#    'display_phone': '(323) 531-2314',
#    'distance': 8878.367351483248},
#   {'id': '-JEqW3dxvfCAsOP-IjbsNA',
#    'alias': 'adrians-taco-trailer-los-angeles',
#    'name': 'Adrians Taco Trailer',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HBFjU5UiAyv9NdYwWWigsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/adrians-taco-trailer-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 53,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 34.0317476, 'longitude': -118.2319277},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1000 S Mateo St',
#     'address2': None,
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90021',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1000 S Mateo St', 'Los Angeles, CA 90021']},
#    'phone': '+13237153735',
#    'display_phone': '(323) 715-3735',
#    'distance': 8884.58028399605},
#   {'id': 'iKCpdatfHBS4j7FfJNo1uA',
#    'alias': 'bennys-tacos-and-rotisserie-chicken-culver-city-culver-city',
#    'name': "Benny's Tacos & Rotisserie Chicken - Culver City",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/C4U56ezR6cHSFEnwV6nKqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bennys-tacos-and-rotisserie-chicken-culver-city-culver-city?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 851,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 34.020608, 'longitude': -118.404542},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '10401 Venice Blvd',
#     'address2': 'Ste 101-B',
#     'address3': None,
#     'city': 'Culver City',
#     'zip_code': '90232',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['10401 Venice Blvd',
#      'Ste 101-B',
#      'Culver City, CA 90232']},
#    'phone': '+14242988327',
#    'display_phone': '(424) 298-8327',
#    'distance': 8915.12503623696},
#   {'id': 'wD5YDkvpRQ5x-EYSfmYY-w',
#    'alias': 'poquito-más-studio-city-2',
#    'name': 'Poquito Más',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9xClkoOkpYK3x-co3Tzd8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/poquito-m%C3%A1s-studio-city-2?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 423,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 34.13474, 'longitude': -118.3615},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3701 Cahuenga Blvd',
#     'address2': 'Ste 1',
#     'address3': '',
#     'city': 'Studio City',
#     'zip_code': '91604',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3701 Cahuenga Blvd',
#      'Ste 1',
#      'Studio City, CA 91604']},
#    'phone': '+18187608226',
#    'display_phone': '(818) 760-8226',
#    'distance': 8926.619742380119},
#   {'id': 'GkD1r-Vi2cKr_3bZKohszQ',
#    'alias': 'sagus-natural-los-angeles-3',
#    'name': "SaGu's Natural",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Np1_9pZsgKWX9WXSmblwUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sagus-natural-los-angeles-3?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 2,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 34.099144388109,
#     'longitude': -118.235659562051},
#    'transactions': [],
#    'location': {'address1': '1900 N San Fernando Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90065',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1900 N San Fernando Rd', 'Los Angeles, CA 90065']},
#    'phone': '+12133042127',
#    'display_phone': '(213) 304-2127',
#    'distance': 8931.079375544909},
#   {'id': 'RalYlLHfgQl3rXtPFdOPig',
#    'alias': 'baja-fresh-los-angeles-13',
#    'name': 'Baja Fresh',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3YohTqPWj0nSMPABztKy7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baja-fresh-los-angeles-13?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 110,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'tex-mex', 'title': 'Tex-Mex'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 34.126444056905,
#     'longitude': -118.263958692961},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2921 Los Feliz Blvd',
#     'address2': 'Ste 1',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90039',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2921 Los Feliz Blvd',
#      'Ste 1',
#      'Los Angeles, CA 90039']},
#    'phone': '+13236440164',
#    'display_phone': '(323) 644-0164',
#    'distance': 8942.244879223277},
#   {'id': 'aJhZioM5AO-j6XqbZrsIHA',
#    'alias': 'la-estrella-mexican-food-2-los-angeles',
#    'name': 'La Estrella Mexican Food 2',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2eo6kwJJ2Ij1vbdSOkkvQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-estrella-mexican-food-2-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 1,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 34.054613, 'longitude': -118.224588},
#    'transactions': [],
#    'location': {'address1': '538 N Mission Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90033',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['538 N Mission Rd', 'Los Angeles, CA 90033']},
#    'phone': '+13239194010',
#    'display_phone': '(323) 919-4010',
#    'distance': 8950.36913842034},
#   {'id': '82WCs3yjCEfYElzVJEnkgQ',
#    'alias': 'primo-burgers-los-angeles',
#    'name': 'Primo Burgers',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZIMg7qFWuLKAdXhKISAifg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/primo-burgers-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 19,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.98161, 'longitude': -118.30927},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '6325 S Western Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90047',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6325 S Western Ave', 'Los Angeles, CA 90047']},
#    'phone': '+13237531605',
#    'display_phone': '(323) 753-1605',
#    'distance': 8959.085393101497},
#   {'id': 'b90QuvHHHHuithwqbuuh7g',
#    'alias': 'classic-patio-furniture-warehouse-outlet-hayward',
#    'name': 'Classic Patio Furniture - Warehouse Outlet',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qbu8iuuYRU_OevKfXVJOYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/classic-patio-furniture-warehouse-outlet-hayward?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 6,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 37.611, 'longitude': -122.06105},
#    'transactions': [],
#    'location': {'address1': '1582 Zephyr Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Hayward',
#     'zip_code': '94542',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1582 Zephyr Ave', 'Hayward, CA 94542']},
#    'phone': '+15107506055',
#    'display_phone': '(510) 750-6055',
#    'distance': 8962.518834867391},
#   {'id': 'K37ysgSUSHfYy9PNZCJqcg',
#    'alias': 'cosina-alambre-26-los-angeles-2',
#    'name': 'Cosina Alambre 26',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/J4qh55olJCGRHYl3MlQxTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cosina-alambre-26-los-angeles-2?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 1,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 34.02035, 'longitude': -118.40493},
#    'transactions': [],
#    'location': {'address1': '10429 Venice Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90034',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['10429 Venice Blvd', 'Los Angeles, CA 90034']},
#    'phone': '+13104258645',
#    'display_phone': '(310) 425-8645',
#    'distance': 8962.518834867391},
#   {'id': 'WaNwZ0pU_HDETCSlvpAk3A',
#    'alias': 'alameda-night-market-vernon-4',
#    'name': 'Alameda Night Market',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tCSsgExGhnZMN0xC2WuebA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alameda-night-market-vernon-4?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 3,
#    'categories': [{'alias': 'farmersmarket', 'title': 'Farmers Market'},
#     {'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 34.01724, 'longitude': -118.24042},
#    'transactions': [],
#    'location': {'address1': '1774 E 21st St',
#     'address2': None,
#     'address3': '',
#     'city': 'Vernon',
#     'zip_code': '90058',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1774 E 21st St', 'Vernon, CA 90058']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 8965.38025102302},
#   {'id': 'Blb0Eso-wdKdBkqr80UHdA',
#    'alias': 'tacos-los-guichos-los-angeles',
#    'name': 'Tacos Los Guichos',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/X04L1CYaB7GNtwgpKRdhpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-los-guichos-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 155,
#    'categories': [{'alias': 'foodstands', 'title': 'Food Stands'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.988833, 'longitude': -118.2790517},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '320 W Slauson Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90003',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['320 W Slauson Ave', 'Los Angeles, CA 90003']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 8981.51888209869},
#   {'id': 'E9u5nLX5rqhv6z1ddt2caA',
#    'alias': 'asadas-el-infierno-los-angeles-2',
#    'name': 'Asadas El Infierno',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IKxDKrcRt30JcJXVik2-bQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/asadas-el-infierno-los-angeles-2?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 1,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 34.115092, 'longitude': -118.248558},
#    'transactions': [],
#    'location': {'address1': '3150 N San Fernando Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90065',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3150 N San Fernando Rd', 'Los Angeles, CA 90065']},
#    'phone': '+13235424165',
#    'display_phone': '(323) 542-4165',
#    'distance': 8982.996332456261},
#   {'id': '5dd7D6C3dKtpxzgsR5R1uA',
#    'alias': 'javiers-century-city-los-angeles',
#    'name': "Javier's Century City",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KPk_gn4qutolyU6qxAw_pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/javiers-century-city-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 1315,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 34.0599599, 'longitude': -118.41982},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '10250 Santa Monica Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90067',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['10250 Santa Monica Blvd', 'Los Angeles, CA 90067']},
#    'phone': '+14243138143',
#    'display_phone': '(424) 313-8143',
#    'distance': 8984.877767628835},
#   {'id': '1iH0JS9j41v_i7hxuUL8Yw',
#    'alias': 'tocaya-century-city-los-angeles-2',
#    'name': 'Tocaya - Century City',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iYwnur8o63S3de8lgwND5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tocaya-century-city-los-angeles-2?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 381,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 34.0599599, 'longitude': -118.41982},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '10250 Santa Monica Blvd',
#     'address2': 'Ste 2300',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90067',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['10250 Santa Monica Blvd',
#      'Ste 2300',
#      'Los Angeles, CA 90067']},
#    'phone': '+14242556956',
#    'display_phone': '(424) 255-6956',
#    'distance': 8984.877767628835},
#   {'id': '2uSEc3MYOgn90KRcR6U7tg',
#    'alias': 'chipotle-mexican-grill-los-angeles-47',
#    'name': 'Chipotle Mexican Grill',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9R1qgcf-unL60p4DxRxSHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chipotle-mexican-grill-los-angeles-47?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 93,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 34.05996, 'longitude': -118.41982},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '10250 Santa Monica Blvd',
#     'address2': 'Ste FC2',
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90067',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['10250 Santa Monica Blvd',
#      'Ste FC2',
#      'Los Angeles, CA 90067']},
#    'phone': '+14242040026',
#    'display_phone': '(424) 204-0026',
#    'distance': 8984.877767628835},
#   {'id': 'vjG3O1cMVB2-nLMpETzXag',
#    'alias': 'tacos-al-carbon-los-angeles',
#    'name': 'Tacos Al Carbon',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NvbCC0PuBljNdvlzKb0L_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-al-carbon-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 3,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.9844876088192,
#     'longitude': -118.291352266103},
#    'transactions': [],
#    'location': {'address1': '6104 S Vermont Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90044',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6104 S Vermont Ave', 'Los Angeles, CA 90044']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9008.916612133948},
#   {'id': 'jkpfw3Qa3yRibEwi5yQaQA',
#    'alias': 'juanitos-tacos-los-angeles-3',
#    'name': "Juanito's Tacos",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/r5_TsDD7CDhKEcNvAXHxAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/juanitos-tacos-los-angeles-3?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 7,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 34.018816871589536,
#     'longitude': -118.23799817055166},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1950 E Washington Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90021',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1950 E Washington Blvd', 'Los Angeles, CA 90021']},
#    'phone': '+13237934576',
#    'display_phone': '(323) 793-4576',
#    'distance': 9035.932957477948},
#   {'id': 'waRbhQZK8Rosc1kFod77Hw',
#    'alias': 'puro-texcoco-los-angeles-2',
#    'name': 'Puro Texcoco',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hgFOndy-PC2kjvql7Zfgng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/puro-texcoco-los-angeles-2?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 11,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 33.9889793395996,
#     'longitude': -118.276977539062},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '222 W Slauson Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90003',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['222 W Slauson Ave', 'Los Angeles, CA 90003']},
#    'phone': '+13232351880',
#    'display_phone': '(323) 235-1880',
#    'distance': 9042.871582747359},
#   {'id': 'HE8yOk2Ty25InmpStznKMw',
#    'alias': 'taqueria-la-guadalupana-los-angeles-2',
#    'name': 'Taqueria La Guadalupana',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y7XiUx6eey_dHTLx3eexGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-la-guadalupana-los-angeles-2?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 70,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 34.10272, 'longitude': -118.2366},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '2100 Cypress Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90065',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2100 Cypress Ave', 'Los Angeles, CA 90065']},
#    'phone': '+13235940509',
#    'display_phone': '(323) 594-0509',
#    'distance': 9047.54741606432},
#   {'id': 'MjWMuWJNlxNXr-KmAXL8KQ',
#    'alias': 'madre-oaxacan-restaurant-and-mezcaleria-los-angeles-6',
#    'name': 'Madre Oaxacan Restaurant and Mezcaleria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ah5yPIchEgAR-cNyJNBVGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/madre-oaxacan-restaurant-and-mezcaleria-los-angeles-6?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 966,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 34.0287002, 'longitude': -118.4114403},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '10426 National Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90034',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['10426 National Blvd', 'Los Angeles, CA 90034']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9052.659394031836},
#   {'id': 'H3cJ7V_VQWDL161wxHgERw',
#    'alias': 'quesadilla-melis-los-angeles',
#    'name': "Quesadilla Meli's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/T1E1Wk5f2z7_IaGTaOhlSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/quesadilla-melis-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 15,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 34.0986293019372,
#     'longitude': -118.233750741395},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2700 Future St',
#     'address2': '',
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90065',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2700 Future St', 'Los Angeles, CA 90065']},
#    'phone': '+13233854652',
#    'display_phone': '(323) 385-4652',
#    'distance': 9060.69198889137},
#   {'id': 'Xi-imMqeZt_QGTVrvck2-w',
#    'alias': 'hook-it-up-food-truck-los-angeles',
#    'name': 'hook it up  food truck',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dngoEZYvV-zXd5I17s5H4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hook-it-up-food-truck-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 1,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 34.003454, 'longitude': -118.252466},
#    'transactions': [],
#    'location': {'address1': '4415 Hooper Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90011',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4415 Hooper Ave', 'Los Angeles, CA 90011']},
#    'phone': '+14247890096',
#    'display_phone': '(424) 789-0096',
#    'distance': 9065.291049307672},
#   {'id': 'q54b_YSNpYJv-wpeVZwvRg',
#    'alias': 'salvamex-los-angeles-2',
#    'name': 'Salvamex',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VLgfKOwEgKcuw4q3BTU0mQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salvamex-los-angeles-2?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 45,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'salvadoran', 'title': 'Salvadoran'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 34.1008796691895,
#     'longitude': -118.235191345215},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1910 Cypress Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90065',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1910 Cypress Ave', 'Los Angeles, CA 90065']},
#    'phone': '+13232233914',
#    'display_phone': '(323) 223-3914',
#    'distance': 9068.771792406042},
#   {'id': 'euuPObkvWFhpW12taZPqeA',
#    'alias': 'tacos-el-birrias-estillo-tijuana-los-angeles',
#    'name': 'Tacos El Birrias Estillo Tijuana',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LyHcdOBjO8i9SZVvohVPPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-el-birrias-estillo-tijuana-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 6,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 34.1008, 'longitude': -118.23494},
#    'transactions': [],
#    'location': {'address1': '1900 Cypress Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90065',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1900 Cypress Ave', 'Los Angeles, CA 90065']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9069.129302035777},
#   {'id': 'WR3_Dw58mCnmGq-cW7H0vw',
#    'alias': 'ditroit-taqueria-los-angeles',
#    'name': 'Ditroit Taqueria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oxivDykjZRAPVWYMsl3u-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ditroit-taqueria-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 56,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 34.03314716116565,
#     'longitude': -118.229120390524},
#    'transactions': [],
#    'location': {'address1': '2117 Violet St',
#     'address2': '',
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90021',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2117 Violet St', 'Los Angeles, CA 90021']},
#    'phone': '+12135597257',
#    'display_phone': '(213) 559-7257',
#    'distance': 9069.5243948728},
#   {'id': 'n8cs5yUAG6XVn52eMChCNw',
#    'alias': 'damian-los-angeles',
#    'name': 'Damian',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7oLbFi7gPhf08VEtNj_V0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/damian-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 152,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 34.03357583, 'longitude': -118.22909483},
#    'transactions': [],
#    'location': {'address1': '2132 E 7th Pl',
#     'address2': '',
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90021',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2132 E 7th Pl', 'Los Angeles, CA 90021']},
#    'phone': '+12132700178',
#    'display_phone': '(213) 270-0178',
#    'distance': 9071.838431949216},
#   {'id': '4Ci1Go2yuau36vRnwBqEkw',
#    'alias': 'city-club-restaurant-los-angeles',
#    'name': 'City Club Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/if2lIWUeD-gjNoFN7eU-wQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/city-club-restaurant-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 19,
#    'categories': [{'alias': 'divebars', 'title': 'Dive Bars'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 34.0310385078192,
#     'longitude': -118.230038657784},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1029 S Santa Fe Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90021',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1029 S Santa Fe Ave', 'Los Angeles, CA 90021']},
#    'phone': '+12138911562',
#    'display_phone': '(213) 891-1562',
#    'distance': 9075.51529970061},
#   {'id': '8sVUX79Ffk0_ObIpwVBNaw',
#    'alias': 'el-milagro-los-angeles-2',
#    'name': 'El Milagro',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cgftdNwObgwD9lb2Qm5i7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-milagro-los-angeles-2?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 47,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 34.0774040222168,
#     'longitude': -118.224678039551},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '419 N Ave 19',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90031',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['419 N Ave 19', 'Los Angeles, CA 90031']},
#    'phone': '+13234235566',
#    'display_phone': '(323) 423-5566',
#    'distance': 9079.118737023136},
#   {'id': '4w3rjG89m7kEWiwdwrET_Q',
#    'alias': 'el-taco-mexicano-no-2-los-angeles',
#    'name': 'El Taco Mexicano No 2',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YD8KhToL3IKl_vAl6ESV8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-taco-mexicano-no-2-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 72,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 34.00369, 'longitude': -118.25186},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1300 E Vernon Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90011',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1300 E Vernon Ave', 'Los Angeles, CA 90011']},
#    'phone': '+13232331677',
#    'display_phone': '(323) 233-1677',
#    'distance': 9086.963013749386},
#   {'id': '9meY_RQZMnkcWkkeONpeeQ',
#    'alias': 'elens-los-angeles',
#    'name': "Elen's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hE7JFwmsQ65pIG5e9ObkHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/elens-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 1,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 33.9933411782285,
#     'longitude': -118.266981582036},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '4626 Avalon Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90011',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4626 Avalon Blvd', 'Los Angeles, CA 90011']},
#    'phone': '+13233639355',
#    'display_phone': '(323) 363-9355',
#    'distance': 9095.183615322492},
#   {'id': '6MWElD7t-Gz17452OlFy9Q',
#    'alias': 'tortilleria-la-california-los-angeles',
#    'name': 'Tortilleria La California',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iMHg4pTDYOoF2mB202_pvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tortilleria-la-california-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 38,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 34.10468, 'longitude': -118.2375},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '2241 Cypress Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90065',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2241 Cypress Ave', 'Los Angeles, CA 90065']},
#    'phone': '+13232218940',
#    'display_phone': '(323) 221-8940',
#    'distance': 9098.783437768885},
#   {'id': 'OKom4poViaaWD_fEz1Rk0A',
#    'alias': 'el-pollo-loco-los-angeles-65',
#    'name': 'El Pollo Loco',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/y0qKipkXu934oWyntJWVEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-pollo-loco-los-angeles-65?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 192,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 34.11449900707426, 'longitude': -118.2459697},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3070 San Fernando Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90065',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3070 San Fernando Rd', 'Los Angeles, CA 90065']},
#    'phone': '+13232561938',
#    'display_phone': '(323) 256-1938',
#    'distance': 9101.594294713008},
#   {'id': 'JWpK0iuk9Cf2Vxvt5keVWQ',
#    'alias': 'mr-fish-and-mex-grill-los-angeles-2',
#    'name': 'Mr. Fish & Mex Grill',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OXl0XLNspgP4oW107ZGkvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mr-fish-and-mex-grill-los-angeles-2?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 55,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.9878859, 'longitude': -118.3645205},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '4949 W Slauson Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90056',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4949 W Slauson Ave', 'Los Angeles, CA 90056']},
#    'phone': '+13232900801',
#    'display_phone': '(323) 290-0801',
#    'distance': 9108.875189722357},
#   {'id': 'YSENUwpVk_puPIy3XOZ5EA',
#    'alias': 'tierra-caliente-los-angeles',
#    'name': 'Tierra Caliente',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/m2uYVxzO3i1IIP8prvWitw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tierra-caliente-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 21,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 34.102743377367595,
#     'longitude': -118.23582355828381},
#    'transactions': [],
#    'location': {'address1': '2910 Division St',
#     'address2': None,
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90065',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2910 Division St', 'Los Angeles, CA 90065']},
#    'phone': '+13239870311',
#    'display_phone': '(323) 987-0311',
#    'distance': 9111.84626639017},
#   {'id': 'fELzlqERcbsyRr0UVKWgcQ',
#    'alias': 'taqueria-la-michoacana-los-angeles',
#    'name': 'Taqueria La Michoacana',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AK39lrtWOZx82V0mrYaqPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-la-michoacana-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 8,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'importedfood', 'title': 'Imported Food'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 33.9878240192095,
#     'longitude': -118.364468291402},
#    'transactions': [],
#    'location': {'address1': '4949 Slauson Ave A-2',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90056',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4949 Slauson Ave A-2', 'Los Angeles, CA 90056']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9112.969596562198},
#   {'id': 'cGXKcWY09uCLfjI-0QdBUA',
#    'alias': 'yaiquesadillas-los-angeles',
#    'name': 'yaiquesadillas',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yaiquesadillas-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 1,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 34.0835758712, 'longitude': -118.226020709},
#    'transactions': [],
#    'location': {'address1': '556 North San Fernando Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90065',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['556 North San Fernando Rd', 'Los Angeles, CA 90065']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9117.100657269477},
#   {'id': 'jDkDrZ5PF7CSolAIfaQUrg',
#    'alias': 'tacos-la-morenita-los-angeles-3',
#    'name': 'Tacos La Morenita',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jDGgInKUCxJAeclmYzsTRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-la-morenita-los-angeles-3?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 43,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 34.0953941345215,
#     'longitude': -118.231010437012},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1250 N San Fernando Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90065',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1250 N San Fernando Rd', 'Los Angeles, CA 90065']},
#    'phone': '+13237875539',
#    'display_phone': '(323) 787-5539',
#    'distance': 9132.300938194945},
#   {'id': 'StnoIhUtHxARjHYoTO7G_w',
#    'alias': 'don-sazon-restaurant-los-angeles',
#    'name': 'Don Sazon Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IzD-kF3nb3eZHfPTyxsS7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/don-sazon-restaurant-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 3,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'diners', 'title': 'Diners'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 33.999654, 'longitude': -118.256265},
#    'transactions': [],
#    'location': {'address1': '4800 Central Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90011',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4800 Central Ave', 'Los Angeles, CA 90011']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9133.21551220393},
#   {'id': 'UD1S7s8ILxiclZ9BZzUVQg',
#    'alias': 'casa-galindo-los-angeles',
#    'name': 'Casa Galindo',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-galindo-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 1,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 33.98329, 'longitude': -118.29114},
#    'transactions': [],
#    'location': {'address1': '6210 Vermont Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90044',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6210 Vermont Ave', 'Los Angeles, CA 90044']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9134.681212715564},
#   {'id': 'khxFQH1HHSBqlvYUdVvekA',
#    'alias': 'el-pulpo-mojado-los-angeles',
#    'name': 'El Pulpo Mojado',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-pulpo-mojado-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 1,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 33.98329, 'longitude': -118.29114},
#    'transactions': ['delivery'],
#    'location': {'address1': '6210 S Vermont Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90044',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6210 S Vermont Ave', 'Los Angeles, CA 90044']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9136.276711120865},
#   {'id': 'zvy7kNF2k5_0Y0mCSBLUVQ',
#    'alias': 'perro-110-los-angeles',
#    'name': 'Perro 110',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/pVZ8rnor2r8E72vbPaWi0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/perro-110-los-angeles?adjust_creative=X5Beq4YFcWJGL3TdpUzGVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=X5Beq4YFcWJGL3TdpUzGVg',
#    'review_count': 8,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'streetvendors', 'title': 'Street Vendors'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 34.00153, 'longitude': -118.25674},
#    'transactions': [],
#    'location': {'address1': '4607 S Central Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90011',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4607 S Central Ave', 'Los Angeles, CA 90011']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9154.83906837774}],
#  'total': 9600,
#  'region': {'center': {'longitude': -118.32138061523438,
#    'latitude': 34.0615895441259}}}

# %%
yelp_rest.to_csv('yelp_csv2.csv', index = False)

# %%
yelp_90034 = pd.DataFrame(None)

for offset_num in range(0, 800, 50):
    
    
    
    #set params
    
    api_url = 'https://api.yelp.com/v3/businesses/search'
    params = {'location' : '90034', 'sort_by' : 'distance', 
             'offset': offset_num, 'limit': 50}

    #set key/headers
    
    api_key = 'lHNoGitPyFt2COwE_nMbGDQZM6pmgd0scwqiEDSiV22PKvVjt_eDZxHLJNN5rv1gmMFvlzN05dx0hxuXr47GM1iAB_gbsD4RlpBsvPC7myo4RfzSTwAiHDZYU-3mYXYx'
    headers = {'Authorization' : 'Bearer %s' % api_key}
    
    #make an API request
    
    api_request = requests.get(api_url, params = params, headers=headers) 
    
    #get response for a single page of 50
    
    json.loads(api_request.text)
    api_response = json.loads(api_request.text)
    businesses = api_response['businesses']

    
    business_data = {
    'name' : [],
    'review_count' : [],
    'rating':[],
    'address1':[],
    'address2':[],
    'city':[],
    'city':[],
    'state':[],
    'zip_code':[],
    'url':[],
    'id':[], 
    'latitude':[], 'longitude':[], 'alias':[], 'title':[], 'price':[]
    }



    for business in businesses:
        name = business['name']
        business_data['name'].append(name)
        #print(name)

        review_count = business['review_count']
        business_data['review_count'].append(review_count)
        #print(review_count)

        rating = business['rating']
        business_data['rating'].append(rating)
        #print(rating)

        address1 = business['location']['address1']
        business_data['address1'].append(address1)
        #print(address1)

        address2 = business['location']['address2']
        business_data['address2'].append(address2)
        #print(address2)

        city = business['location']['city']
        business_data['city'].append(city)
        #print(city)

        state = business['location']['state']
        business_data['state'].append(state)
        #print(state)

        zip_code = business['location']['zip_code']
        business_data['zip_code'].append(zip_code)
        #print(zip_code)

        url = business['url']
        business_data['url'].append(url)
        #print(url)

        id = business['id']
        business_data['id'].append(id)
        #print(id)
        
        latitude = business['coordinates']['latitude']
        business_data['latitude'].append(latitude)
        
        long = business['coordinates']['longitude']
        business_data['longitude'].append(long)
                                          
        alias = business['categories'][0]['alias']
        business_data['alias'].append(alias)
        
        title = business['categories'][0]['title']
        business_data['title'].append(title)
        
        
        def hello(num):
            return businesses[num]['price']
        
        for i in range (0,50,1):  
            try:
                hello(i)
            except Exception:
                price = 'NA'
            else:
                price = (businesses[i]['price'])
                
        business_data['price'].append(price)

        #print('-'*75)
        
        # convert Python dict to a pandas dataframe
        
        df = pd.DataFrame(business_data)
        
    yelp_90034 = yelp_90034.append(df)
        
    print(offset_num)
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750

# %%
yelp_90034.to_csv('yelp_90034.csv', index = False)

# %%
yelp_90036 = pd.DataFrame(None)

for offset_num in range(0, 800, 50):
    
    
    
    #set params
    
    api_url = 'https://api.yelp.com/v3/businesses/search'
    params = {'location' : '90036', 'sort_by' : 'distance', 
             'offset': offset_num, 'limit': 50}

    #set key/headers
    
    api_key = 'lHNoGitPyFt2COwE_nMbGDQZM6pmgd0scwqiEDSiV22PKvVjt_eDZxHLJNN5rv1gmMFvlzN05dx0hxuXr47GM1iAB_gbsD4RlpBsvPC7myo4RfzSTwAiHDZYU-3mYXYx'
    headers = {'Authorization' : 'Bearer %s' % api_key}
    
    #make an API request
    
    api_request = requests.get(api_url, params = params, headers=headers) 
    
    #get response for a single page of 50
    
    json.loads(api_request.text)
    api_response = json.loads(api_request.text)
    businesses = api_response['businesses']

    
    business_data = {
    'name' : [],
    'review_count' : [],
    'rating':[],
    'address1':[],
    'address2':[],
    'city':[],
    'city':[],
    'state':[],
    'zip_code':[],
    'url':[],
    'id':[], 
    'latitude':[], 'longitude':[], 'alias':[], 'title':[], 'price':[]
    }



    for business in businesses:
        name = business['name']
        business_data['name'].append(name)
        #print(name)

        review_count = business['review_count']
        business_data['review_count'].append(review_count)
        #print(review_count)

        rating = business['rating']
        business_data['rating'].append(rating)
        #print(rating)

        address1 = business['location']['address1']
        business_data['address1'].append(address1)
        #print(address1)

        address2 = business['location']['address2']
        business_data['address2'].append(address2)
        #print(address2)

        city = business['location']['city']
        business_data['city'].append(city)
        #print(city)

        state = business['location']['state']
        business_data['state'].append(state)
        #print(state)

        zip_code = business['location']['zip_code']
        business_data['zip_code'].append(zip_code)
        #print(zip_code)

        url = business['url']
        business_data['url'].append(url)
        #print(url)

        id = business['id']
        business_data['id'].append(id)
        #print(id)
        
        latitude = business['coordinates']['latitude']
        business_data['latitude'].append(latitude)
        
        long = business['coordinates']['longitude']
        business_data['longitude'].append(long)
                                          
        alias = business['categories'][0]['alias']
        business_data['alias'].append(alias)
        
        title = business['categories'][0]['title']
        business_data['title'].append(title)
        
        
        def hello(num):
            return businesses[num]['price']
        
        for i in range (0,50,1):  
            try:
                hello(i)
            except Exception:
                price = 'NA'
            else:
                price = (businesses[i]['price'])
                
        business_data['price'].append(price)

        #print('-'*75)
        
        # convert Python dict to a pandas dataframe
        
        df = pd.DataFrame(business_data)
        
    yelp_90036 = yelp_90036.append(df)
        
    print(offset_num)
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750

# %%
yelp_90036.to_csv('yelp_90036.csv', index = False)

# %%
yelp_90026 = pd.DataFrame(None)

for offset_num in range(0, 800, 50):
    
    
    
    #set params
    
    api_url = 'https://api.yelp.com/v3/businesses/search'
    params = {'location' : '90026', 'sort_by' : 'distance', 
             'offset': offset_num, 'limit': 50}

    #set key/headers
    
    api_key = 'lHNoGitPyFt2COwE_nMbGDQZM6pmgd0scwqiEDSiV22PKvVjt_eDZxHLJNN5rv1gmMFvlzN05dx0hxuXr47GM1iAB_gbsD4RlpBsvPC7myo4RfzSTwAiHDZYU-3mYXYx'
    headers = {'Authorization' : 'Bearer %s' % api_key}
    
    #make an API request
    
    api_request = requests.get(api_url, params = params, headers=headers) 
    
    #get response for a single page of 50
    
    json.loads(api_request.text)
    api_response = json.loads(api_request.text)
    businesses = api_response['businesses']

    
    business_data = {
    'name' : [],
    'review_count' : [],
    'rating':[],
    'address1':[],
    'address2':[],
    'city':[],
    'city':[],
    'state':[],
    'zip_code':[],
    'url':[],
    'id':[], 
    'latitude':[], 'longitude':[], 'alias':[], 'title':[], 'price':[]
    }



    for business in businesses:
        name = business['name']
        business_data['name'].append(name)
        #print(name)

        review_count = business['review_count']
        business_data['review_count'].append(review_count)
        #print(review_count)

        rating = business['rating']
        business_data['rating'].append(rating)
        #print(rating)

        address1 = business['location']['address1']
        business_data['address1'].append(address1)
        #print(address1)

        address2 = business['location']['address2']
        business_data['address2'].append(address2)
        #print(address2)

        city = business['location']['city']
        business_data['city'].append(city)
        #print(city)

        state = business['location']['state']
        business_data['state'].append(state)
        #print(state)

        zip_code = business['location']['zip_code']
        business_data['zip_code'].append(zip_code)
        #print(zip_code)

        url = business['url']
        business_data['url'].append(url)
        #print(url)

        id = business['id']
        business_data['id'].append(id)
        #print(id)
        
        latitude = business['coordinates']['latitude']
        business_data['latitude'].append(latitude)
        
        long = business['coordinates']['longitude']
        business_data['longitude'].append(long)
                                          
        alias = business['categories'][0]['alias']
        business_data['alias'].append(alias)
        
        title = business['categories'][0]['title']
        business_data['title'].append(title)
        
        
        def hello(num):
            return businesses[num]['price']
        
        for i in range (0,50,1):  
            try:
                hello(i)
            except Exception:
                price = 'NA'
            else:
                price = (businesses[i]['price'])
                
        business_data['price'].append(price)

        #print('-'*75)
        
        # convert Python dict to a pandas dataframe
        
        df = pd.DataFrame(business_data)
        
    yelp_90026 = yelp_90026.append(df)
        
    print(offset_num)
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750

# %%
yelp_90026.to_csv('yelp_90026.csv', index = False)
